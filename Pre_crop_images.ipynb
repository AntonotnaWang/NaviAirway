# %% [markdown]
# # Generate pre-cropped EXACT09 and LIDC-IDRI for faster training

# %%
import os
import numpy as np
import skimage.io as io
import SimpleITK as sitk


# build the raw_data_dict for train

raw_data_dict = dict()

# LIDC-IDRI data
LIDC_IDRI_file_path = "/data/Airway/LIDC-IDRI_3D/annotated_data"
LIDC_IDRI_raw_path = LIDC_IDRI_file_path+"/image"
LIDC_IDRI_label_path = LIDC_IDRI_file_path+"/label"

LIDC_IDRI_raw_names = os.listdir(LIDC_IDRI_raw_path)
LIDC_IDRI_raw_names.sort()

LIDC_IDRI_label_names = os.listdir(LIDC_IDRI_label_path)
LIDC_IDRI_label_names.sort()

case_names = []

for case in LIDC_IDRI_raw_names:
    temp = case.split(".")[0]
    #print(temp)
    case_names.append(temp)
    raw_data_dict["LIDC_IDRI_"+temp]={}
    raw_data_dict["LIDC_IDRI_"+temp]["image"]=LIDC_IDRI_raw_path+"/"+case

for case in LIDC_IDRI_label_names:
    temp = case.split(".")[0]
    #print(temp)
    if temp in case_names:
        raw_data_dict["LIDC_IDRI_"+temp]["label"]=LIDC_IDRI_label_path+"/"+case

LIDC_IDRI_data_dict = raw_data_dict





# EXACT09 train data

raw_data_dict = dict()

EXACT09_file_path = "/data/Airway/EXACT09_3D"
EXACT09_train_raw_path = EXACT09_file_path+"/train"
EXACT09_train_label_path = EXACT09_file_path+"/train_label"

EXACT09_raw_names = os.listdir(EXACT09_train_raw_path)
EXACT09_raw_names.sort()

EXACT09_label_names = os.listdir(EXACT09_train_label_path)
EXACT09_label_names.sort()

case_names = []

for case in EXACT09_raw_names:
    temp = case.split(".")[0]
    case_names.append(temp)
    raw_data_dict["EXACT09_"+temp]={}
    raw_data_dict["EXACT09_"+temp]["image"]=EXACT09_train_raw_path+"/"+case

for case in EXACT09_label_names:
    temp = case.split("_")[0]
    if temp in case_names:
        raw_data_dict["EXACT09_"+temp]["label"]=EXACT09_train_label_path+"/"+case

EXACT09_data_dict = raw_data_dict

# %%
print(LIDC_IDRI_data_dict)
print(EXACT09_data_dict)
# Out:
# {'LIDC_IDRI_0066': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0066.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0066.nii.gz'}, 'LIDC_IDRI_0140': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0140.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0140.nii.gz'}, 'LIDC_IDRI_0328': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0328.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0328.nii.gz'}, 'LIDC_IDRI_0376': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0376.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0376.nii.gz'}, 'LIDC_IDRI_0403': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0403.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0403.nii.gz'}, 'LIDC_IDRI_0430': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0430.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0430.nii.gz'}, 'LIDC_IDRI_0438': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0438.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0438.nii.gz'}, 'LIDC_IDRI_0441': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0441.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0441.nii.gz'}, 'LIDC_IDRI_0490': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0490.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0490.nii.gz'}, 'LIDC_IDRI_0529': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0529.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0529.nii.gz'}, 'LIDC_IDRI_0606': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0606.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0606.nii.gz'}, 'LIDC_IDRI_0621': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0621.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0621.nii.gz'}, 'LIDC_IDRI_0648': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0648.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0648.nii.gz'}, 'LIDC_IDRI_0651': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0651.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0651.nii.gz'}, 'LIDC_IDRI_0657': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0657.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0657.nii.gz'}, 'LIDC_IDRI_0663': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0663.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0663.nii.gz'}, 'LIDC_IDRI_0673': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0673.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0673.nii.gz'}, 'LIDC_IDRI_0676': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0676.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0676.nii.gz'}, 'LIDC_IDRI_0684': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0684.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0684.nii.gz'}, 'LIDC_IDRI_0696': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0696.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0696.nii.gz'}, 'LIDC_IDRI_0698': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0698.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0698.nii.gz'}, 'LIDC_IDRI_0710': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0710.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0710.nii.gz'}, 'LIDC_IDRI_0722': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0722.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0722.nii.gz'}, 'LIDC_IDRI_0744': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0744.nii.gz', 'label': '/data/Airway/LIDC-IDRI_3D/annotated_data/label/0744.nii.gz'}, 'LIDC_IDRI_0757': {'image': '/data/Airway/LIDC-IDRI_3D/annotated_data/image/0757.nii.gz', 'label': '/data/Airwa ...
# {'EXACT09_CASE01': {'image': '/data/Airway/EXACT09_3D/train/CASE01.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE01_label.nii.gz'}, 'EXACT09_CASE02': {'image': '/data/Airway/EXACT09_3D/train/CASE02.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE02_label.nii.gz'}, 'EXACT09_CASE03': {'image': '/data/Airway/EXACT09_3D/train/CASE03.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE03_label.nii.gz'}, 'EXACT09_CASE04': {'image': '/data/Airway/EXACT09_3D/train/CASE04.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE04_label.nii.gz'}, 'EXACT09_CASE05': {'image': '/data/Airway/EXACT09_3D/train/CASE05.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE05_label.nii.gz'}, 'EXACT09_CASE06': {'image': '/data/Airway/EXACT09_3D/train/CASE06.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE06_label.nii.gz'}, 'EXACT09_CASE07': {'image': '/data/Airway/EXACT09_3D/train/CASE07.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE07_label.nii.gz'}, 'EXACT09_CASE08': {'image': '/data/Airway/EXACT09_3D/train/CASE08.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE08_label.nii.gz'}, 'EXACT09_CASE09': {'image': '/data/Airway/EXACT09_3D/train/CASE09.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE09_label.nii.gz'}, 'EXACT09_CASE10': {'image': '/data/Airway/EXACT09_3D/train/CASE10.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE10_label.nii.gz'}, 'EXACT09_CASE11': {'image': '/data/Airway/EXACT09_3D/train/CASE11.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE11_label.nii.gz'}, 'EXACT09_CASE12': {'image': '/data/Airway/EXACT09_3D/train/CASE12.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE12_label.nii.gz'}, 'EXACT09_CASE13': {'image': '/data/Airway/EXACT09_3D/train/CASE13.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE13_label.nii.gz'}, 'EXACT09_CASE14': {'image': '/data/Airway/EXACT09_3D/train/CASE14.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE14_label.nii.gz'}, 'EXACT09_CASE15': {'image': '/data/Airway/EXACT09_3D/train/CASE15.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE15_label.nii.gz'}, 'EXACT09_CASE16': {'image': '/data/Airway/EXACT09_3D/train/CASE16.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE16_label.nii.gz'}, 'EXACT09_CASE17': {'image': '/data/Airway/EXACT09_3D/train/CASE17.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE17_label.nii.gz'}, 'EXACT09_CASE18': {'image': '/data/Airway/EXACT09_3D/train/CASE18.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE18_label.nii.gz'}, 'EXACT09_CASE19': {'image': '/data/Airway/EXACT09_3D/train/CASE19.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE19_label.nii.gz'}, 'EXACT09_CASE20': {'image': '/data/Airway/EXACT09_3D/train/CASE20.nii.gz', 'label': '/data/Airway/EXACT09_3D/train_label/CASE20_label.nii.gz'}}

# %%
def crop_one_3d_img(input_img, crop_cube_size, stride):
    # input_img: 3d matrix, numpy.array
    assert isinstance(crop_cube_size, (int, tuple))
    if isinstance(crop_cube_size, int):
        crop_cube_size=np.array([crop_cube_size, crop_cube_size, crop_cube_size])
    else:
        assert len(crop_cube_size)==3
    
    assert isinstance(stride, (int, tuple))
    if isinstance(stride, int):
        stride=np.array([stride, stride, stride])
    else:
        assert len(stride)==3
    
    img_shape=input_img.shape
    
    total=len(np.arange(0, img_shape[0], stride[0]))*len(np.arange(0, img_shape[1], stride[1]))*len(np.arange(0, img_shape[2], stride[2]))
    
    count=0
    
    crop_list = []
    
    for i in np.arange(0, img_shape[0], stride[0]):
        for j in np.arange(0, img_shape[1], stride[1]):
            for k in np.arange(0, img_shape[2], stride[2]):
                print('crop one 3d img progress : '+str(np.int(count/total*100))+'%', end='\r')
                if i+crop_cube_size[0]<=img_shape[0]:
                    x_start_input=i
                    x_end_input=i+crop_cube_size[0]
                    x_start_output=i
                    x_end_output=i+stride[0]
                else:
                    x_start_input=img_shape[0]-crop_cube_size[0]
                    x_end_input=img_shape[0]
                    x_start_output=i
                    x_end_output=img_shape[0]
                
                if j+crop_cube_size[1]<=img_shape[1]:
                    y_start_input=j
                    y_end_input=j+crop_cube_size[1]
                    y_start_output=j
                    y_end_output=j+stride[1]
                else:
                    y_start_input=img_shape[1]-crop_cube_size[1]
                    y_end_input=img_shape[1]
                    y_start_output=j
                    y_end_output=img_shape[1]
                
                if k+crop_cube_size[2]<=img_shape[2]:
                    z_start_input=k
                    z_end_input=k+crop_cube_size[2]
                    z_start_output=k
                    z_end_output=k+stride[2]
                else:
                    z_start_input=img_shape[2]-crop_cube_size[2]
                    z_end_input=img_shape[2]
                    z_start_output=k
                    z_end_output=img_shape[2]
                
                crop_temp=input_img[x_start_input:x_end_input, y_start_input:y_end_input, z_start_input:z_end_input]
                crop_list.append(np.array(crop_temp, dtype=np.float))
                
                count=count+1
                
    return crop_list

# %% [markdown]
# #### pre crop LIDC-IDRI

# %%
crop_cube_size=(256, 256, 256)
stride=(128,128,128)

# -----INPUT-----
output_file_path = "Precrop_dataset_for_LIDC-IDRI"

if not os.path.exists(output_file_path+"/image/"):
    os.makedirs(output_file_path+"/image/")

if not os.path.exists(output_file_path+"/label/"):
    os.makedirs(output_file_path+"/label/")

raw_data_dict = LIDC_IDRI_data_dict
# -----END-----

for i, case in enumerate(raw_data_dict.keys()):
    raw_img = io.imread(raw_data_dict[case]["image"], plugin='simpleitk')
    label_img = io.imread(raw_data_dict[case]["label"], plugin='simpleitk')
    
    raw_img_crop_list = crop_one_3d_img(raw_img, crop_cube_size=crop_cube_size, stride=stride)
    label_img_crop_list = crop_one_3d_img(label_img, crop_cube_size=crop_cube_size, stride=stride)
    
    assert len(raw_img_crop_list)==len(label_img_crop_list)
    
    for idx in range(len(raw_img_crop_list)):
        print("progress: "+str(idx)+"th crop | "+str(i)+"th 3d img: "+str(case), end="\r")
        
        #sitk.WriteImage(sitk.GetImageFromArray(raw_img_crop_list[idx]), output_file_path+"/image/"+case+"_"+str(idx)+".nii.gz")
        #sitk.WriteImage(sitk.GetImageFromArray(label_img_crop_list[idx]), output_file_path+"/label/"+case+"_"+str(idx)+".nii.gz")
        
        np.save(output_file_path+"/image/"+case+"_"+str(idx)+".npy", raw_img_crop_list[idx])
        np.save(output_file_path+"/label/"+case+"_"+str(idx)+".npy", label_img_crop_list[idx])

# %% [markdown]
# #### pre crop EXACT09

# %%
crop_cube_size=(128,128,128)
stride=(64,64,64)

# -----INPUT-----
output_file_path = "Precrop_dataset_for_EXACT09"

if not os.path.exists(output_file_path+"/image/"):
    os.makedirs(output_file_path+"/image/")

if not os.path.exists(output_file_path+"/label/"):
    os.makedirs(output_file_path+"/label/")

raw_data_dict = EXACT09_data_dict
# -----END-----

for i, case in enumerate(raw_data_dict.keys()):
    raw_img = io.imread(raw_data_dict[case]["image"], plugin='simpleitk')
    label_img = io.imread(raw_data_dict[case]["label"], plugin='simpleitk')
    
    raw_img_crop_list = crop_one_3d_img(raw_img, crop_cube_size=crop_cube_size, stride=stride)
    label_img_crop_list = crop_one_3d_img(label_img, crop_cube_size=crop_cube_size, stride=stride)
    
    assert len(raw_img_crop_list)==len(label_img_crop_list)
    
    for idx in range(len(raw_img_crop_list)):
        print("progress: "+str(idx)+"th crop | "+str(i)+"th 3d img: "+str(case), end="\r")
        
        #sitk.WriteImage(sitk.GetImageFromArray(raw_img_crop_list[idx]), output_file_path+"/image/"+case+"_"+str(idx)+".nii.gz")
        #sitk.WriteImage(sitk.GetImageFromArray(label_img_crop_list[idx]), output_file_path+"/label/"+case+"_"+str(idx)+".nii.gz")
        
        np.save(output_file_path+"/image/"+case+"_"+str(idx)+".npy", raw_img_crop_list[idx])
        np.save(output_file_path+"/label/"+case+"_"+str(idx)+".npy", label_img_crop_list[idx])
